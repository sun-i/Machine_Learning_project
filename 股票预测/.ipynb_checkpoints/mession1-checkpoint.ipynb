# %%
import pandas as pd
import numpy as np

# import mplfinance as mpf

# %%
df=pd.read_csv(r"apple.csv")

# %%
df.index=pd.to_datetime(df.Date)#索引转为日期
#df = df.iloc[::-1]#由于获取的数据是倒序的，需要将其调整为正序
mpf.plot(df[-200:],type='candle')#绘制最近200天的数据

# %%
df=df.drop(['Date','Adj Close','Volume'],axis=1)
df
# Out:
#              Open        High         Low       Close
# 0        0.128348    0.128906    0.128348    0.128348
# 1        0.122210    0.122210    0.121652    0.121652
# 2        0.113281    0.113281    0.112723    0.112723
# 3        0.115513    0.116071    0.115513    0.115513
# 4        0.118862    0.119420    0.118862    0.118862
# ...           ...         ...         ...         ...
# 10592  141.110001  141.800003  136.029999  136.500000
# 10593  136.690002  137.649994  133.729996  134.509995
# 10594  135.110001  135.199997  131.320007  132.369995
# 10595  131.389999  133.250000  129.889999  132.300003
# 10596  132.979996  136.809998  132.750000  135.449997
#
# [10597 rows x 4 columns]

# %%
dataX=[]#属性
dataY=[]#标签
k=0
tempX=[]#储存某个历史10590天数据
tempY=[]#储存某个未来6天数据
for index, rows in df.iterrows():
    if k<10590:
        k+=1
        tempX.append([rows['Open'],rows['Close'],rows['High'],rows['Low']])
        continue
    if k<10596:
        k+=1
        tempY.append([rows['Open'],rows['Close'],rows['High'],rows['Low']])
        continue
    dataX.append(tempX[:])
    dataY.append(tempY[:])
 
    tempX=tempX[1:]+tempY[:1]
 
    tempY=tempY[1:]
    tempY.append([rows['Open'],rows['Close'],rows['High'],rows['Low']])
dataX.append(tempX[:])#加上最后一项
dataY.append(tempY[:])#加上最后一项

# %%
### 使用了 LSTM模型 取apple数据中后596个数据进行训练 并训练后的模型对2023年1月5日后的5天进行预测

import torch
import torch.utils.data as Data
 
dataX=torch.tensor(dataX,dtype=torch.float)#列表转Tensor
dataY=torch.tensor(dataY,dtype=torch.float)#列表转Tensor
 
dataset=Data.TensorDataset(dataX,dataY)

train_size=int(0.8*len(dataset))
test_size=len(dataset)-train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])#以8:2比例划分训练集和测试集
 
train_loader = Data.DataLoader(
            dataset=train_dataset,
            batch_size=64,
            shuffle=False
        )
test_loader = Data.DataLoader(
            dataset=test_dataset,
            batch_size=64,
            shuffle=False
        )

# %%
from torch.nn import LSTM,Module,Linear
class MyModel(Module):
    def __init__(self):
        super(MyModel,self).__init__()
        self.lstm=LSTM(input_size=4,hidden_size=4,num_layers=2,batch_first=True)
        self.linear=Linear(42360,24)#将结果映射到7天的数据
    def forward(self,x):
        return self.linear(self.lstm(x)[0].reshape(-1,42360))

# %%
import torch.nn.functional as F
model=MyModel()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
lossList=[]#记录训练loss
lossListTest=[]#记录测试loss
for epoch in range(200):
    loss_nowEpoch=[]
    model.train()
    for step, (batch_x, batch_y) in enumerate(train_loader):
        out=model(batch_x)#模型输入
        Loss = F.mse_loss(out,batch_y.view(-1,24))#loss计算，将batch_y从(64,7,4)变形为(64,28)
        optimizer.zero_grad()#当前batch的梯度不会再用到，所以清除梯度
        Loss.backward()#反向传播计算梯度
        optimizer.step()#更新参数
        loss_nowEpoch.append(Loss.item())
        break
    lossList.append(sum(loss_nowEpoch)/len(loss_nowEpoch))
 
    loss_nowEpochTest = []
    model.eval()
    for step, (batch_x, batch_y) in enumerate(test_loader):
        out = model(batch_x)
        Loss = F.mse_loss(out, batch_y.view(-1, 24))  # 将batch_y从(64,7,4)变形为(64,28)
        loss_nowEpochTest.append(Loss.item())
        break
    lossListTest.append(sum(loss_nowEpochTest)/len(loss_nowEpochTest))
 
    print(">>> EPOCH{} averTrainLoss:{:.3f} averTestLoss:{:.3f}".format(epoch+1, lossList[-1],lossListTest[-1]))
# Out:
# >>> EPOCH1 averTrainLoss:19232.688 averTestLoss:16469.842
# >>> EPOCH2 averTrainLoss:17036.648 averTestLoss:14409.339
# >>> EPOCH3 averTrainLoss:14940.735 averTestLoss:12451.621
# >>> EPOCH4 averTrainLoss:12946.926 averTestLoss:10604.974

# %%
 
import matplotlib.pyplot as plt
plt.plot(list(range(200)),lossList,label='Train')
plt.plot(list(range(200)),lossListTest,label='Test')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
import torch

# %%
# 使用了 LSTM模型 取apple数据中后596个数据进行训练 并训练后的模型对2023年1月5日后的5天进行预测
from torch import nn
time_step = 20
input_size = 4
learning_rate = 0.001
hidden_size = 64
num_layers = 1
end_lenth=6500
class Bi_LSTM(nn.Module):
    """搭建LSTM"""
    def __init__(self):
        super(Bi_LSTM, self).__init__()
        # LSTM层
        self.lstm = nn.LSTM(input_size=input_size,      # 输入单元个数
                            hidden_size=hidden_size,    # 隐藏单元个数
                            num_layers=num_layers,      # 隐藏层数
                            batch_first=True,           # True：[batch, time_step, input_size] False:[time_step, batch, input_size]
                            bidirectional=True)

        # 输出层
        self.output_layers = nn.Linear(in_features=hidden_size*2,    # 输入特征个数
                                       out_features=1)  # 输出特征个数

    def forward(self, x):
        lstm_out, (h_n, h_c) = self.lstm(x, None)   #
        # print(lstm_out.shape)
        output = self.output_layers(lstm_out[:, -1, :])    # 选择最后一个时刻的LSTM作为输出
        return output

# %%
import torch.nn.functional as F
model=Bi_LSTM()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
lossList=[]#记录训练loss
lossListTest=[]#记录测试loss
for epoch in range(200):
    loss_nowEpoch=[]
    model.train()
    for step, (batch_x, batch_y) in enumerate(train_loader):
        out=model(batch_x)#模型输入
        Loss = F.mse_loss(out,batch_y.view(-1,24))#loss计算，将batch_y从(64,7,4)变形为(64,28)
        optimizer.zero_grad()#当前batch的梯度不会再用到，所以清除梯度
        Loss.backward()#反向传播计算梯度
        optimizer.step()#更新参数
        loss_nowEpoch.append(Loss.item())
        break
    lossList.append(sum(loss_nowEpoch)/len(loss_nowEpoch))
 
    loss_nowEpochTest = []
    model.eval()
    for step, (batch_x, batch_y) in enumerate(test_loader):
        out = model(batch_x)
        Loss = F.mse_loss(out, batch_y.view(-1, 24))  # 将batch_y从(64,7,4)变形为(64,28)
        loss_nowEpochTest.append(Loss.item())
        break
    lossListTest.append(sum(loss_nowEpochTest)/len(loss_nowEpochTest))
 
    print(">>> EPOCH{} averTrainLoss:{:.3f} averTestLoss:{:.3f}".format(epoch+1, lossList[-1],lossListTest[-1]))
# Out:
# C:\Users\qaz25\AppData\Local\Temp\ipykernel_4984\2087677215.py:11: UserWarning: Using a target size (torch.Size([1, 24])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   Loss = F.mse_loss(out,batch_y.view(-1,24))#loss计算，将batch_y从(64,7,4)变形为(64,28)
# C:\Users\qaz25\AppData\Local\Temp\ipykernel_4984\2087677215.py:23: UserWarning: Using a target size (torch.Size([1, 24])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   Loss = F.mse_loss(out, batch_y.view(-1, 24))  # 将batch_y从(64,7,4)变形为(64,28)
# >>> EPOCH1 averTrainLoss:19222.734 averTestLoss:18581.160
# >>> EPOCH2 averTrainLoss:19187.209 averTestLoss:18554.037
# >>> EPOCH3 averTrainLoss:19155.547 averTestLoss:18527.688
# >>> EPOCH4 averTrainLoss:19127.494 averTestLoss:18501.035
# >>> EPOCH5 averTrainLoss:19100.225 averTestLoss:18472.906
# >>> EPOCH6 averTrainLoss:19071.873 averTestLoss:18442.775
# >>> EPOCH7 averTrainLoss:19041.703 averTestLoss:18410.715
# >>> EPOCH8 averTrainLoss:19010.059 averTestLoss:18377.877
# >>> EPOCH9 averTrainLoss:18978.533 averTestLoss:18345.850
# >>> EPOCH10 averTrainLoss:18948.385 averTestLoss:18315.287
# >>> EPOCH11 averTrainLoss:18918.820 averTestLoss:18288.498
# >>> EPOCH12 averTrainLoss:18890.172 averTestLoss:18265.658
# >>> EPOCH13 averTrainLoss:18865.018 averTestLoss:18244.779
# >>> EPOCH14 averTrainLoss:18842.992 averTestLoss:18224.498
# >>> EPOCH15 averTrainLoss:18822.188 averTestLoss:18204.068
# >>> EPOCH16 averTrainLoss:18801.396 averTestLoss:18183.076
# >>> EPOCH17 averTrainLoss:18779.885 averTestLoss:18161.463
# >>> EPOCH18 averTrainLoss:18757.453 averTestLoss:18138.969
# >>> EPOCH19 averTrainLoss:18733.883 averTestLoss:18114.736
# >>> EPOCH20 averTrainLoss:18708.561 averTestLoss:18087.596
# >>> EPOCH21 averTrainLoss:18680.521 averTestLoss:18056.803
# >>> EPOCH22 averTrainLoss:18649.088 averTestLoss:18022.916
# >>> EPOCH23 averTrainLoss:18614.717 averTestLoss:17988.332
# >>> EPOCH24 averTrainLoss:18579.693 averTestLoss:17956.164
# >>> EPOCH25 averTrainLoss:18547.141 averTestLoss:17926.686
# >>> EPOCH26 averTrainLoss:18517.312 averTestLoss:17898.682
# >>> EPOCH27 averTrainLoss:18488.912 averTestLoss:17871.494
# >>> EPOCH28 averTrainLoss:18461.441 averTestLoss:17844.379
# >>> EPOCH29 averTrainLoss:18434.436 averTestLoss:17816.900
# >>> EPOCH30 averTrainLoss:18407.609 averTestLoss:17789.084
# >>> EPOCH31 averTrainLoss:18380.428 averTestLoss:17760.180
# >>> EPOCH32 averTrainLoss:18351.506 averTestLoss:17729.264
# >>> EPOCH33 averTrainLoss:18319.811 averTestLoss:17696.707
# >>> EPOCH34 averTrainLoss:18285.848 averTestLoss:17666.248
# >>> EPOCH35 averTrainLoss:18253.738 averTestLoss:17642.557
# >>> EPOCH36 averTrainLoss:18228.539 averTestLoss:17621.545
# >>> EPOCH37 averTrainLoss:18206.404 averTestLoss:17599.213
# >>> EPOCH38 averTrainLoss:18183.607 averTestLoss:17574.748
# >>> EPOCH39 averTrainLoss:18159.330 averTestLoss:17548.662
# >>> EPOCH40 averTrainLoss:18133.502 averTestLoss:17522.104
# >>> EPOCH41 averTrainLoss:18106.729 averTestLoss:17496.229
# >>> EPOCH42 averTrainLoss:18080.301 averTestLoss:17471.875
# >>> EPOCH43 averTrainLoss:18055.504 averTestLoss:17449.562
# >>> EPOCH44 averTrainLoss:18033.068 averTestLoss:17429.252
# >>> EPOCH45 averTrainLoss:18012.850 averTestLoss:17410.230
# >>> EPOCH46 averTrainLoss:17993.963 averTestLoss:17391.832
# >>> EPOCH47 averTrainLoss:17975.533 averTestLoss:17373.898
# >>> EPOCH48 averTrainLoss:17957.213 averTestLoss:17356.564
# >>> EPOCH49 averTrainLoss:17939.188 averTestLoss:17339.863
# >>> EPOCH50 averTrainLoss:17921.750 averTestLoss:17323.621
# >>> EPOCH51 averTrainLoss:17904.916 averTestLoss:17307.631
# >>> EPOCH52 averTrainLoss:17888.471 averTestLoss:17291.744
# >>> EPOCH53 averTrainLoss:17872.203 averTestLoss:17275.850
# >>> EPOCH54 averTrainLoss:17855.943 averTestLoss:17259.834
# >>> EPOCH55 averTrainLoss:17839.541 averTestLoss:17243.527
# >>> EPOCH56 averTrainLoss:17822.814 averTestLoss:17226.666
# >>> EPOCH57 averTrainLoss:17805.557 averTestLoss:17209.137
# >>> EPOCH58 averTrainLoss:17787.846 averTestLoss:17191.824
# >>> EPOCH59 averTrainLoss:17770.545 averTestLoss:17175.846
# >>> EPOCH60 averTrainLoss:17754.391 averTestLoss:17160.299
# >>> EPOCH61 averTrainLoss:17738.592 averTestLoss:17144.793
# >>> EPOCH62 averTrainLoss:17722.834 averTestLoss:17129.330
# >>> EPOCH63 averTrainLoss:17707.111 averTestLoss:17113.900
# >>> EPOCH64 averTrainLoss:17691.432 averTestLoss:17098.506
# >>> EPOCH65 averTrainLoss:17675.787 averTestLoss:17083.150
# >>> EPOCH66 averTrainLoss:17660.174 averTestLoss:17067.818
# >>> EPOCH67 averTrainLoss:17644.582 averTestLoss:17052.494
# >>> EPOCH68 averTrainLoss:17628.990 averTestLoss:17037.143
# >>> EPOCH69 averTrainLoss:17613.357 averTestLoss:17021.676
# >>> EPOCH70 averTrainLoss:17597.578 averTestLoss:17005.916
# >>> EPOCH71 averTrainLoss:17581.459 averTestLoss:16989.506
# >>> EPOCH72 averTrainLoss:17564.631 averTestLoss:16971.865
# >>> EPOCH73 averTrainLoss:17546.600 averTestLoss:16952.662
# >>> EPOCH74 averTrainLoss:17527.264 averTestLoss:16933.529
# >>> EPOCH75 averTrainLoss:17508.197 averTestLoss:16916.592
# >>> EPOCH76 averTrainLoss:17491.014 averTestLoss:16900.588
# >>> EPOCH77 averTrainLoss:17474.695 averTestLoss:16884.941
# >>> EPOCH78 averTrainLoss:17458.758 averTestLoss:16869.459
# >>> EPOCH79 averTrainLoss:17443.006 averTestLoss:16854.049
# >>> EPOCH80 averTrainLoss:17427.334 averTestLoss:16838.684
# >>> EPOCH81 averTrainLoss:17411.713 averTestLoss:16823.350
# >>> EPOCH82 averTrainLoss:17396.123 averTestLoss:16808.047
# >>> EPOCH83 averTrainLoss:17380.566 averTestLoss:16792.771
# >>> EPOCH84 averTrainLoss:17365.037 averTestLoss:16777.525
# >>> EPOCH85 averTrainLoss:17349.543 averTestLoss:16762.309
# >>> EPOCH86 averTrainLoss:17334.076 averTestLoss:16747.119
# >>> EPOCH87 averTrainLoss:17318.639 averTestLoss:16731.959
# >>> EPOCH88 averTrainLoss:17303.225 averTestLoss:16716.822
# >>> EPOCH89 averTrainLoss:17287.836 averTestLoss:16701.693
# >>> EPOCH90 averTrainLoss:17272.455 averTestLoss:16686.551
# >>> EPOCH91 averTrainLoss:17257.064 averTestLoss:16671.346
# >>> EPOCH92 averTrainLoss:17241.604 averTestLoss:16655.961
# >>> EPOCH93 averTrainLoss:17225.965 averTestLoss:16640.154
# >>> EPOCH94 averTrainLoss:17209.891 averTestLoss:16623.396
# >>> EPOCH95 averTrainLoss:17192.842 averTestLoss:16604.566
# >>> EPOCH96 averTrainLoss:17173.678 averTestLoss:16581.967
# >>> EPOCH97 averTrainLoss:17150.680 averTestLoss:16556.928
# >>> EPOCH98 averTrainLoss:17125.250 averTestLoss:16538.266
# >>> EPOCH99 averTrainLoss:17106.322 averTestLoss:16523.010
# >>> EPOCH100 averTrainLoss:17090.814 averTestLoss:16507.812
# >>> EPOCH101 averTrainLoss:17075.363 averTestLoss:16492.619
# >>> EPOCH102 averTrainLoss:17059.920 averTestLoss:16477.439
# >>> EPOCH103 averTrainLoss:17044.486 averTestLoss:16462.271
# >>> EPOCH104 averTrainLoss:17029.066 averTestLoss:16447.123
# >>> EPOCH105 averTrainLoss:17013.666 averTestLoss:16431.996
# >>> EPOCH106 averTrainLoss:16998.283 averTestLoss:16416.889
# >>> EPOCH107 averTrainLoss:16982.924 averTestLoss:16401.805
# >>> EPOCH108 averTrainLoss:16967.592 averTestLoss:16386.748
# >>> EPOCH109 averTrainLoss:16952.283 averTestLoss:16371.716
# >>> EPOCH110 averTrainLoss:16936.998 averTestLoss:16356.711
# >>> EPOCH111 averTrainLoss:16921.742 averTestLoss:16341.730
# >>> EPOCH112 averTrainLoss:16906.514 averTestLoss:16326.780
# >>> EPOCH113 averTrainLoss:16891.309 averTestLoss:16311.854
# >>> EPOCH114 averTrainLoss:16876.135 averTestLoss:16296.957
# >>> EPOCH115 averTrainLoss:16860.986 averTestLoss:16282.085
# >>> EPOCH116 averTrainLoss:16845.867 averTestLoss:16267.239
# >>> EPOCH117 averTrainLoss:16830.770 averTestLoss:16252.421
# >>> EPOCH118 averTrainLoss:16815.701 averTestLoss:16237.625
# >>> EPOCH119 averTrainLoss:16800.656 averTestLoss:16222.856
# >>> EPOCH120 averTrainLoss:16785.639 averTestLoss:16208.112
# >>> EPOCH121 averTrainLoss:16770.641 averTestLoss:16193.387
# >>> EPOCH122 averTrainLoss:16755.662 averTestLoss:16178.681
# >>> EPOCH123 averTrainLoss:16740.701 averTestLoss:16163.984
# >>> EPOCH124 averTrainLoss:16725.752 averTestLoss:16149.293
# >>> EPOCH125 averTrainLoss:16710.797 averTestLoss:16134.579
# >>> EPOCH126 averTrainLoss:16695.814 averTestLoss:16119.804
# >>> EPOCH127 averTrainLoss:16680.756 averTestLoss:16104.847
# >>> EPOCH128 averTrainLoss:16665.482 averTestLoss:16089.362
# >>> EPOCH129 averTrainLoss:16649.631 averTestLoss:16072.575
# >>> EPOCH130 averTrainLoss:16632.482 averTestLoss:16054.565
# >>> EPOCH131 averTrainLoss:16614.389 averTestLoss:16038.780
# >>> EPOCH132 averTrainLoss:16598.486 averTestLoss:16024.265
# >>> EPOCH133 averTrainLoss:16583.727 averTestLoss:16009.777
# >>> EPOCH134 averTrainLoss:16568.998 averTestLoss:15995.312
# >>> EPOCH135 averTrainLoss:16554.289 averTestLoss:15980.866
# >>> EPOCH136 averTrainLoss:16539.600 averTestLoss:15966.438
# >>> EPOCH137 averTrainLoss:16524.924 averTestLoss:15952.026
# >>> EPOCH138 averTrainLoss:16510.271 averTestLoss:15937.638
# >>> EPOCH139 averTrainLoss:16495.641 averTestLoss:15923.266
# >>> EPOCH140 averTrainLoss:16481.025 averTestLoss:15908.913
# >>> EPOCH141 averTrainLoss:16466.428 averTestLoss:15894.581
# >>> EPOCH142 averTrainLoss:16451.855 averTestLoss:15880.266
# >>> EPOCH143 averTrainLoss:16437.299 averTestLoss:15865.972
# >>> EPOCH144 averTrainLoss:16422.760 averTestLoss:15851.695
# >>> EPOCH145 averTrainLoss:16408.242 averTestLoss:15837.437
# >>> EPOCH146 averTrainLoss:16393.744 averTestLoss:15823.199
# >>> EPOCH147 averTrainLoss:16379.263 averTestLoss:15808.978
# >>> EPOCH148 averTrainLoss:16364.801 averTestLoss:15794.777
# >>> EPOCH149 averTrainLoss:16350.359 averTestLoss:15780.598
# >>> EPOCH150 averTrainLoss:16335.935 averTestLoss:15766.430
# >>> EPOCH151 averTrainLoss:16321.531 averTestLoss:15752.284
# >>> EPOCH152 averTrainLoss:16307.142 averTestLoss:15738.155
# >>> EPOCH153 averTrainLoss:16292.773 averTestLoss:15724.044
# >>> EPOCH154 averTrainLoss:16278.423 averTestLoss:15709.952
# >>> EPOCH155 averTrainLoss:16264.091 averTestLoss:15695.878
# >>> EPOCH156 averTrainLoss:16249.777 averTestLoss:15681.819
# >>> EPOCH157 averTrainLoss:16235.481 averTestLoss:15667.778
# >>> EPOCH158 averTrainLoss:16221.199 averTestLoss:15653.755
# >>> EPOCH159 averTrainLoss:16206.937 averTestLoss:15639.751
# >>> EPOCH160 averTrainLoss:16192.695 averTestLoss:15625.762
# >>> EPOCH161 averTrainLoss:16178.466 averTestLoss:15611.789
# >>> EPOCH162 averTrainLoss:16164.255 averTestLoss:15597.833
# >>> EPOCH163 averTrainLoss:16150.060 averTestLoss:15583.896
# >>> EPOCH164 averTrainLoss:16135.883 averTestLoss:15569.974
# >>> EPOCH165 averTrainLoss:16121.723 averTestLoss:15556.069
# >>> EPOCH166 averTrainLoss:16107.581 averTestLoss:15542.179
# >>> EPOCH167 averTrainLoss:16093.452 averTestLoss:15528.304
# >>> EPOCH168 averTrainLoss:16079.340 averTestLoss:15514.445
# >>> EPOCH169 averTrainLoss:16065.245 averTestLoss:15500.603
# >>> EPOCH170 averTrainLoss:16051.164 averTestLoss:15486.776
# >>> EPOCH171 averTrainLoss:16037.102 averTestLoss:15472.964
# >>> EPOCH172 averTrainLoss:16023.052 averTestLoss:15459.168
# >>> EPOCH173 averTrainLoss:16009.019 averTestLoss:15445.387
# >>> EPOCH174 averTrainLoss:15995.003 averTestLoss:15431.621
# >>> EPOCH175 averTrainLoss:15981.001 averTestLoss:15417.871
# >>> EPOCH176 averTrainLoss:15967.011 averTestLoss:15404.134
# >>> EPOCH177 averTrainLoss:15953.039 averTestLoss:15390.411
# >>> EPOCH178 averTrainLoss:15939.082 averTestLoss:15376.704
# >>> EPOCH179 averTrainLoss:15925.138 averTestLoss:15363.011
# >>> EPOCH180 averTrainLoss:15911.211 averTestLoss:15349.332
# >>> EPOCH181 averTrainLoss:15897.296 averTestLoss:15335.665
# >>> EPOCH182 averTrainLoss:15883.392 averTestLoss:15322.015
# >>> EPOCH183 averTrainLoss:15869.507 averTestLoss:15308.375
# >>> EPOCH184 averTrainLoss:15855.630 averTestLoss:15294.749
# >>> EPOCH185 averTrainLoss:15841.770 averTestLoss:15281.134
# >>> EPOCH186 averTrainLoss:15827.922 averTestLoss:15267.532
# >>> EPOCH187 averTrainLoss:15814.083 averTestLoss:15253.940
# >>> EPOCH188 averTrainLoss:15800.261 averTestLoss:15240.362
# >>> EPOCH189 averTrainLoss:15786.445 averTestLoss:15226.789
# >>> EPOCH190 averTrainLoss:15772.642 averTestLoss:15213.227
# >>> EPOCH191 averTrainLoss:15758.844 averTestLoss:15199.667
# >>> EPOCH192 averTrainLoss:15745.052 averTestLoss:15186.109
# >>> EPOCH193 averTrainLoss:15731.263 averTestLoss:15172.548
# >>> EPOCH194 averTrainLoss:15717.469 averTestLoss:15158.977
# >>> EPOCH195 averTrainLoss:15703.665 averTestLoss:15145.375
# >>> EPOCH196 averTrainLoss:15689.840 averTestLoss:15131.724
# >>> EPOCH197 averTrainLoss:15675.964 averTestLoss:15117.969
# >>> EPOCH198 averTrainLoss:15661.993 averTestLoss:15104.023
# >>> EPOCH199 averTrainLoss:15647.843 averTestLoss:15089.690
# >>> EPOCH200 averTrainLoss:15633.335 averTestLoss:15074.630

# %%
 
import matplotlib.pyplot as plt
plt.plot(list(range(200)),lossList,label='Train')
plt.plot(list(range(200)),lossListTest,label='Test')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# 使用了 GRUNet模型 取apple数据中后596个数据进行训练 并训练后的模型对2023年1月5日后的5天进行预测
time_step = 20
input_size = 4
learning_rate = 0.001
end_lenth=6500
class GRUNet(nn.Module):
 
    def __init__(self, input_size=4):
        super(GRUNet, self).__init__()
        self.rnn = nn.GRU(
            input_size=input_size,
            hidden_size=64,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )
        self.out = nn.Sequential(
            nn.Linear(128, 1)
        )
 
    def forward(self, x):
        r_out, (h_n, h_c) = self.rnn(x, None)  # None 表示 hidden state 会用全0的 state
        out = self.out(r_out[:, -1])
        print(out.shape)
        return out

# %%
import torch.nn.functional as F
model=GRUNet()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
lossList=[]#记录训练loss
lossListTest=[]#记录测试loss
for epoch in range(200):
    loss_nowEpoch=[]
    model.train()
    for step, (batch_x, batch_y) in enumerate(train_loader):
        out=model(batch_x)#模型输入
        Loss = F.mse_loss(out,batch_y.view(-1,24))#loss计算，将batch_y从(64,7,4)变形为(64,28)
        optimizer.zero_grad()#当前batch的梯度不会再用到，所以清除梯度
        Loss.backward()#反向传播计算梯度
        optimizer.step()#更新参数
        loss_nowEpoch.append(Loss.item())
        break
    lossList.append(sum(loss_nowEpoch)/len(loss_nowEpoch))
 
    loss_nowEpochTest = []
    model.eval()
    for step, (batch_x, batch_y) in enumerate(test_loader):
        out = model(batch_x)
        Loss = F.mse_loss(out, batch_y.view(-1, 24))  # 将batch_y从(64,7,4)变形为(64,28)
        loss_nowEpochTest.append(Loss.item())
        break
    lossListTest.append(sum(loss_nowEpochTest)/len(loss_nowEpochTest))
 
    print(">>> EPOCH{} averTrainLoss:{:.3f} averTestLoss:{:.3f}".format(epoch+1, lossList[-1],lossListTest[-1]))
# Out:
# torch.Size([1, 1])
# C:\Users\qaz25\AppData\Local\Temp\ipykernel_4984\4208201321.py:11: UserWarning: Using a target size (torch.Size([1, 24])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   Loss = F.mse_loss(out,batch_y.view(-1,24))#loss计算，将batch_y从(64,7,4)变形为(64,28)
# torch.Size([1, 1])
# >>> EPOCH1 averTrainLoss:19296.105 averTestLoss:18635.674
# torch.Size([1, 1])
# C:\Users\qaz25\AppData\Local\Temp\ipykernel_4984\4208201321.py:23: UserWarning: Using a target size (torch.Size([1, 24])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   Loss = F.mse_loss(out, batch_y.view(-1, 24))  # 将batch_y从(64,7,4)变形为(64,28)
# torch.Size([1, 1])
# >>> EPOCH2 averTrainLoss:19236.111 averTestLoss:18578.635
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH3 averTrainLoss:19176.246 averTestLoss:18519.334
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH4 averTrainLoss:19112.324 averTestLoss:18454.295
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH5 averTrainLoss:19042.516 averTestLoss:18386.080
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH6 averTrainLoss:18972.041 averTestLoss:18323.605
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH7 averTrainLoss:18910.561 averTestLoss:18272.045
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH8 averTrainLoss:18860.877 averTestLoss:18229.303
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH9 averTrainLoss:18819.141 averTestLoss:18190.281
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH10 averTrainLoss:18780.561 averTestLoss:18151.688
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH11 averTrainLoss:18742.264 averTestLoss:18112.844
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH12 averTrainLoss:18703.551 averTestLoss:18074.271
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH13 averTrainLoss:18664.992 averTestLoss:18035.654
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOC
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH172 averTrainLoss:15090.039 averTestLoss:14537.219
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH173 averTrainLoss:15070.991 averTestLoss:14518.523
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH174 averTrainLoss:15051.965 averTestLoss:14499.849
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH175 averTrainLoss:15032.958 averTestLoss:14481.192
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH176 averTrainLoss:15013.973 averTestLoss:14462.559
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH177 averTrainLoss:14995.008 averTestLoss:14443.940
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH178 averTrainLoss:14976.059 averTestLoss:14425.347
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH179 averTrainLoss:14957.136 averTestLoss:14406.771
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH180 averTrainLoss:14938.229 averTestLoss:14388.214
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH181 averTrainLoss:14919.343 averTestLoss:14369.676
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH182 averTrainLoss:14900.477 averTestLoss:14351.159
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH183 averTrainLoss:14881.630 averTestLoss:14332.661
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH184 averTrainLoss:14862.802 averTestLoss:14314.184
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH185 averTrainLoss:14843.992 averTestLoss:14295.727
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH186 averTrainLoss:14825.206 averTestLoss:14277.289
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH187 averTrainLoss:14806.438 averTestLoss:14258.866
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH188 averTrainLoss:14787.690 averTestLoss:14240.469
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH189 averTrainLoss:14768.960 averTestLoss:14222.085
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH190 averTrainLoss:14750.250 averTestLoss:14203.724
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH191 averTrainLoss:14731.560 averTestLoss:14185.382
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH192 averTrainLoss:14712.888 averTestLoss:14167.060
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH193 averTrainLoss:14694.237 averTestLoss:14148.755
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH194 averTrainLoss:14675.605 averTestLoss:14130.470
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH195 averTrainLoss:14656.992 averTestLoss:14112.203
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH196 averTrainLoss:14638.396 averTestLoss:14093.960
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH197 averTrainLoss:14619.823 averTestLoss:14075.730
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH198 averTrainLoss:14601.269 averTestLoss:14057.521
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH199 averTrainLoss:14582.730 averTestLoss:14039.333
# torch.Size([1, 1])
# torch.Size([1, 1])
# >>> EPOCH200 averTrainLoss:14564.215 averTestLoss:14021.163

# %%
 
import matplotlib.pyplot as plt
plt.plot(list(range(200)),lossList,label='Train')
plt.plot(list(range(200)),lossListTest,label='Test')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# # 最终选择LSTM模型

# %%
X=torch.tensor(df[['Open','Close','High','Low']][-590:].to_numpy())
Y=model(X.view(1,590,4).float()).reshape(6,4)
result=pd.DataFrame(torch.vstack((X,Y)).detach().numpy())
result.index=list(df.index[-590:])+[pd.Timestamp('2023-01-5 00:00:00'),pd.Timestamp('2023-01-6 00:00:00'),
                              pd.Timestamp('2023-01-7 00:00:00'),pd.Timestamp('2023-01-8 00:00:00'),
                              pd.Timestamp('2023-01-9 00:00:00'),pd.Timestamp('2023-01-10 00:00:00')]
result.columns=['Open','Close','High','Low']
mpf.plot(result[-21:],type='candle')

# %%
result[-6:]
# Out:
#                   Open       Close        High         Low
# 2023-01-05  149.473221  145.448196  149.940506  144.217606
# 2023-01-06  145.329086  143.183609  146.638992  141.122757
# 2023-01-07  141.076553  136.443787  141.766159  135.963409
# 2023-01-08  136.633499  134.440674  137.594711  133.651138
# 2023-01-09  135.038345  132.283768  135.131363  131.228073
# 2023-01-10  131.297256  132.211197  133.167831  129.791229

# %%
result[-6:].to_excel(excel_writer= r"C:\Users\qaz25\Desktop\mession.xlsx")
